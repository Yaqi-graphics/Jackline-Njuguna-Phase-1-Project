# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaqi-graphics/Jackline-Njuguna-Phase-1-Project/blob/main/phase%201%20project%20-%20feeling%20out%20the%20data-%20jackie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
dataset_1 = pd.read_csv('bom.movie_gross.csv.gz')
display(dataset_1.head())
display(dataset_1.info())
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
# ...

# %%
dataset_2 = pd.read_csv('imdb.name.basics.csv.gz')
display(dataset_2.head())
display(dataset_2.info())
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
dataset_3 = pd.read_csv('imdb.title.akas.csv.gz')
display(dataset_3.head())
display(dataset_3.info())
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ...

# %%
dataset_4 = pd.read_csv('imdb.title.basics.csv.gz')
display(dataset_4.head())
display(dataset_4.info())
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ...

# %%
dataset_5 = pd.read_csv('imdb.title.crew.csv.gz')
display(dataset_5.head())
display(dataset_5.info())
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   tconst     146144 non-null  object
#  1   directors  140417 non-null  object
#  2   writers    110261 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None

# %%
dataset_6 = pd.read_csv('imdb.title.principals.csv.gz')
display(dataset_6.head())
display(dataset_6.info())
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   tconst      1028186 non-null  object
#  1   ordering    1028186 non-null  int64
#  2   nconst      1028186 non-null  object
#  3   category    1028186 non-null  object
#  4   job         177684 non-null   object
#  5   characters  393360 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None

# %%
dataset_7 = pd.read_csv('imdb.title.ratings.csv.gz')
display(dataset_7.head())
display(dataset_7.info())
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None

# %%
dataset_8 = pd.read_csv('rt.movie_info.tsv.gz', error_bad_lines=False)
display(dataset_8.head())
display(dataset_8.info())
# Out:
# <ipython-input-18-3aadda5c631b>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   dataset_8 = pd.read_csv('rt.movie_info.tsv.gz', error_bad_lines=False)
# Skipping line 7: expected 25 fields, saw 28
# Skipping line 58: expected 25 fields, saw 26
# Skipping line 60: expected 25 fields, saw 36
# Skipping line 95: expected 25 fields, saw 34
# Skipping line 161: expected 25 fields, saw 32
# Skipping line 235: expected 25 fields, saw 27
# Skipping line 326: expected 25 fields, saw 30
# Skipping line 425: expected 25 fields, saw 26
# Skipping line 476: expected 25 fields, saw 34
# Skipping line 497: expected 25 fields, saw 38
# Skipping line 504: expected 25 fields, saw 29
# Skipping line 526: expected 25 fields, saw 30
# Skipping line 535: expected 25 fields, saw 27
# Skipping line 554: expected 25 fields, saw 27
# Skipping line 562: expected 25 fields, saw 31
# ...

# %%
#this dataset looks interesting.
#has 26000+ entries.
#variables are:
#vote counts
#popularity
#release date
#"original_title" - which may be good to map over "movie" in dataset 11 below.
dataset_10 = pd.read_csv('tmdb.movies.csv.gz')
display(dataset_10.head())
display(dataset_10.info())
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
dataset_11 = pd.read_csv('tn.movie_budgets.csv.gz')
display(dataset_11.head())
display(dataset_11.info())
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
# ...

# %%
df = dataset_11[['domestic_gross', 'worldwide_gross']]
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df_result_1 = dataset_11['domestic_gross'].str.replace('$', '')
df_result_1
# Out:
# <ipython-input-24-2af7a36152e5>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_result_1 = dataset_11['domestic_gross'].str.replace('$', '')
# 0       760,507,625
# 1       241,063,875
# 2        42,762,350
# 3       459,005,868
# 4       620,181,382
#            ...
# 5777              0
# 5778         48,482
# 5779          1,338
# 5780              0
# 5781        181,041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
df_result_2 = df_result_1.str.replace(',', '')
df_result_2
# Out:
# 0       760507625
# 1       241063875
# 2        42762350
# 3       459005868
# 4       620181382
#           ...
# 5777            0
# 5778        48482
# 5779         1338
# 5780            0
# 5781       181041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
df_result_3 = df_result_2.astype(int)
df_result_3
# Out:
# 0       760507625
# 1       241063875
# 2        42762350
# 3       459005868
# 4       620181382
#           ...
# 5777            0
# 5778        48482
# 5779         1338
# 5780            0
# 5781       181041
# Name: domestic_gross, Length: 5782, dtype: int64

# %%
df_result_4 = np.where(df_result_3 > 100000)
df_result_4
# Out:
# (array([   0,    1,    2, ..., 5773, 5774, 5781]),)

# %%
df_result = np.where(df['domestic_gross'] > df['worldwide_gross'])
df_result
# Out:
# (array([   0,    1,    2, ..., 5643, 5656, 5778]),)

# %%
SUMMARY
Project will consider these datasets: 'tn.movie_budgets.csv.gz' and 'tmdb.movies.csv.gz' and 'imdb.title.basics.csv.gz'


The bottom line for the "success" of a film is the money it makes (Revenue).
Variables that may influence the "success" of a film:

Domestic Gross Revenue
Worldwide Gross Revenue
Average Vote Rating
Vote Count
Popularity
Release Date
Film Title
Genre
Project will create two new features for these datasets:
